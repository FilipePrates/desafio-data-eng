# %% [markdown]
# ### EDA para definir etapas de Limpeza e Tipagem das tranformações de staging
# ### Não automatizado
#    ```sh
#    pip install seaborn
#    ```

# %%
import pandas as pd

localRawDataPath = "cgu_terceirizados_local/year=2024/raw_data.xlsx"
maio = pd.read_excel(localRawDataPath, engine='openpyxl')

# %%
maio.head(1)
# Out:
#    id_terc sg_orgao_sup_tabela_ug  cd_ug_gestora  \
# 0  8761995                   MCOM         413007
#
#                            nm_ug_tabela_ug sg_ug_gestora nr_contrato  \
# 0  AGENCIA NACIONAL DE TELECOMUNICACOES PE     ANATEL-PE  00037/2021
#
#           nr_cnpj                nm_razao_social          nr_cpf  \
# 0  19232342000165  PROACAO SEGURANCA PRIVADA LTD  ***.527.284-**
#
#   nm_terceirizado  ... nm_unidade_prestacao vl_mensal_salario vl_mensal_custo  \
# 0   TIAGO MARTINS  ...            ANATEL PE              2524            5838
#
#   Num_Mes_Carga  Mes_Carga  Ano_Carga  sg_orgao  \
# 0             5       MAIO       2024    ANATEL
#
#                                nm_orgao  cd_orgao_siafi cd_orgao_siape
# 0  AGENCIA NACIONAL DE TELECOMUNICACOES           41231          41231
#
# [1 rows x 23 columns]

# %%
pd.DataFrame(maio.dtypes).transpose()
# Out:
#   id_terc sg_orgao_sup_tabela_ug cd_ug_gestora nm_ug_tabela_ug sg_ug_gestora  \
# 0   int64                 object         int64          object        object
#
#   nr_contrato nr_cnpj nm_razao_social  nr_cpf nm_terceirizado  ...  \
# 0      object   int64          object  object          object  ...
#
#   nm_unidade_prestacao vl_mensal_salario vl_mensal_custo Num_Mes_Carga  \
# 0               object             int64           int64         int64
#
#   Mes_Carga Ano_Carga sg_orgao nm_orgao cd_orgao_siafi cd_orgao_siape
# 0    object     int64   object   object          int64          int64
#
# [1 rows x 23 columns]

# %%
pd.DataFrame(maio.isnull().sum()).transpose()
# Out:
#    id_terc  sg_orgao_sup_tabela_ug  cd_ug_gestora  nm_ug_tabela_ug  \
# 0        0                       0              0                0
#
#    sg_ug_gestora  nr_contrato  nr_cnpj  nm_razao_social  nr_cpf  \
# 0           2819            0        0                0       0
#
#    nm_terceirizado  ...  nm_unidade_prestacao  vl_mensal_salario  \
# 0                1  ...                    47                  0
#
#    vl_mensal_custo  Num_Mes_Carga  Mes_Carga  Ano_Carga  sg_orgao  nm_orgao  \
# 0                0              0          0          0         0         0
#
#    cd_orgao_siafi  cd_orgao_siape
# 0               0               0
#
# [1 rows x 23 columns]

# %%
text_columns = maio.select_dtypes(include=['object']).columns
for col in text_columns:
    value_counts = maio[col].value_counts()
    print(f'Número de valores distintos coluna {col}: {value_counts.shape[0]}')
# Out:
# Número de valores distintos coluna sg_orgao_sup_tabela_ug: 20
# Número de valores distintos coluna nm_ug_tabela_ug: 479
# Número de valores distintos coluna sg_ug_gestora: 393
# Número de valores distintos coluna nr_contrato: 1240
# Número de valores distintos coluna nm_razao_social: 1622
# Número de valores distintos coluna nr_cpf: 68006
# Número de valores distintos coluna nm_terceirizado: 71058
# Número de valores distintos coluna nm_categoria_profissional: 567
# Número de valores distintos coluna nm_escolaridade: 54
# Número de valores distintos coluna nr_jornada: 22
# Número de valores distintos coluna nm_unidade_prestacao: 5089
# Número de valores distintos coluna Mes_Carga: 1
# Número de valores distintos coluna sg_orgao: 72
# Número de valores distintos coluna nm_orgao: 72

# %%
maio['nr_jornada'].value_counts()
# Out:
# nr_jornada
# 44      41412
# 40      11494
# 30       7840
# 41       5929
# 36       4152
# 48       1636
# 20        556
# 22        339
# 42        295
# 25        110
# 45         38
# 84         25
# 10         23
# 15          5
# NI          5
# 35          4
# 26          2
# 37          1
# 28          1
# 27          1
# 23          1
# 11          1
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Get the list of columns that are of type object (text columns)
columns = ["sg_orgao_sup_tabela_ug", 
            #'nm_ug_tabela_ug', 'sg_ug_gestora', "nm_categoria_profissional",
            "nm_escolaridade", "nr_jornada",
            "Mes_Carga", "sg_orgao", "nm_orgao"]
for col in columns:
    # Get the value counts for the specified column
    value_counts = maio.reset_index()[col].astype(str).value_counts()
    
    # Determine the most frequent value
    most_frequent_value = value_counts.index[0]

    # Create a smaller bar plot using Seaborn
    plt.figure(figsize=(7, 4))  # Reduce the figure size
    ax = sns.barplot(x=value_counts.index, y=value_counts.values)
    plt.title(f'Contagem de Valores de {col} \n em cgu_terceirizados/raw_data.xlsx')
    plt.xlabel(col)
    plt.ylabel('Count')
    def select_ticks():
        # Determine the top 4 most frequent values
        top_4_ticks = value_counts.index[:4].tolist()
        # Determine the middle tick
        middle_tick = value_counts.index[len(value_counts) // 2]
        # Determine the last tick
        last_tick = value_counts.index[-1]
        # Combine the selected ticks
        selected_ticks = top_4_ticks + [middle_tick, last_tick]
        # Ensure unique ticks
        selected_ticks = list(dict.fromkeys(selected_ticks))
        return selected_ticks
    selectedTicks = select_ticks()
    ax.set_xticks([value_counts.index.get_loc(tick) for tick in selectedTicks])
    ax.set_xticklabels(selectedTicks, rotation=90)
    plt.show()

# %%
maio.reset_index()["nm_escolaridade"].astype(str).value_counts()
# Out:
# nm_escolaridade
# ENSINO MEDIO COMPLETO            33270
# ENSINO FUNDAMENTAL COMPLETO      16754
# SUPERIOR COMPLETO                 7598
# ENSINO FUNDAMENTAL INCOMPLETO     6216
# SEM EXIGENCIA                     5546
# CURSO TECNICO COMPLETO            1603
# SUPERIOR INCOMPLETO                992
# ENSINO MEDIO INCOMPLETO            883
# ALFABETIZADO                       799
# POS GRADUACAO                       53
# ESPECIALIZACAO/RESIDENCIA           27
# NAO SABE LER/ESCREVER               20
# 14                                  12
# MESTRADO                             8
# DOUTORADO                            8
# 26                                   6
# 15                                   5
# 16                                   5
# 17                                   3
# 20                                   3
# 19                                   3
# 18                                   3
# 28                                   3
# ...

# %%
maio[maio["nm_escolaridade"] == "NAO SABE LER/ESCREVER"].shape

# nm_escolaridade: Nível de escolaridade exigido pela ocupação do terceirizado;
#  https://www.gov.br/cgu/pt-br/acesso-a-informacao/dados-abertos/arquivos/terceirizados/arquivos/descricao-e-dicionario-de-dados.pdf

# Não faz sentido exigir Analfabetismo - provavelmente deveria ser SEM EXIGENCIA.
# Vou tratá-lo como null assim como outros valores espúrios.
# Assumir que foi erro devido à origem declaratória desta informação, sujeito a erros de preenchimento,
# Out:
# (20, 23)
